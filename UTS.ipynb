# %% [markdown]
# Fikri Aziz Biruni - 2702356362

# %% [markdown]
# **1.** [LO 1, LO 2 – 30 Poin] Buatlah model machine learning yang berisi proses pre-processing machinelearning, training, dan hasil dari perbadingan 2 algoritma machine learning yaitu Random Forest danXgboost. Ambil algoritma terbaik dan simpan dengan menggunakan pickle. Seluruh proses disimpan dengan extension .ipynb

# %% [markdown]
# Export Library yang akan digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# membaca file/dataset menggunakan pandas

# %%
df = pd.read_csv('Dataset_B_hotel.csv')

# %% [markdown]
# menunjukkan 5 baris teratas pada dataset

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                         0.0
# 1                  3      Not Selected                         0.0
# 2                  1       Meal Plan 1                         0.0
# 3                  2       Meal Plan 1                         0.0
# 4                  1      Not Selected                         0.0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %% [markdown]
# menunjukkan info (Jumlah data, data type, etc) dari setiap variable yang ada dalam dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     35368 non-null  object
#  6   required_car_parking_space            35005 non-null  float64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# Menunjukkan jumlah missing value dari setiap variable

# %%
print(df.isnull().sum())
# Out:
# Booking_ID                                 0
# no_of_adults                               0
# no_of_children                             0
# no_of_weekend_nights                       0
# no_of_week_nights                          0
# type_of_meal_plan                        907
# required_car_parking_space              1270
# room_type_reserved                         0
# lead_time                                  0
# arrival_year                               0
# arrival_month                              0
# arrival_date                               0
# market_segment_type                        0
# repeated_guest                             0
# no_of_previous_cancellations               0
# no_of_previous_bookings_not_canceled       0
# avg_price_per_room                      1632
# no_of_special_requests                     0
# booking_status                             0
# dtype: int64

# %% [markdown]
# Menunjukkan jumlah baris dan kolom dataset

# %%
df.shape
# Out:
# (36275, 19)

# %% [markdown]
# Menunjukkan jumlah duplicate dan unique values

# %%
print(f'Duplicate Values: {df.duplicated().sum()}')

print(f'\nUnique Values: \n{df.nunique()}')
# Out:
# Duplicate Values: 0
#
# Unique Values:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# market_segment_type                         5
# repeated_guest                              2
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3850
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %% [markdown]
# Menghapus missing value pada datast

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %% [markdown]
# menunjukkan info setelah menghapus missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32607 entries, 0 to 32606
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            32607 non-null  object
#  1   no_of_adults                          32607 non-null  int64
#  2   no_of_children                        32607 non-null  int64
#  3   no_of_weekend_nights                  32607 non-null  int64
#  4   no_of_week_nights                     32607 non-null  int64
#  5   type_of_meal_plan                     32607 non-null  object
#  6   required_car_parking_space            32607 non-null  float64
#  7   room_type_reserved                    32607 non-null  object
#  8   lead_time                             32607 non-null  int64
#  9   arrival_year                          32607 non-null  int64
#  10  arrival_month                         32607 non-null  int64
# ...

# %% [markdown]
# Menghapus/drop column Booking_ID karena hanya berisikan ID unik yang tidak relevan untuk model

# %%
df = df.drop(columns=['Booking_ID'], axis=1)
df
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 32602             3               0                     2                  6
# 32603             2               0                     1                  3
# 32604             2               0                     2                  6
# 32605             2               0                     0                  3
# 32606             2               0                     1                  2
#
# ...

# %% [markdown]
# Melakukan label encoding pada variable target, dikarenakan hanya ada 2 values ('Canceled' atau 'Not_Canceled') maka label encoder sangat sesuai untuk problem tersebut

# %%
encode = LabelEncoder()
df['booking_status'] = encode.fit_transform(df['booking_status'])

# %% [markdown]
# Check untuk sebelum membuat data input dan output, serta untuk menentukan berapa variabel feature_x (17) dan target_y (1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32607 entries, 0 to 32606
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          32607 non-null  int64
#  1   no_of_children                        32607 non-null  int64
#  2   no_of_weekend_nights                  32607 non-null  int64
#  3   no_of_week_nights                     32607 non-null  int64
#  4   type_of_meal_plan                     32607 non-null  object
#  5   required_car_parking_space            32607 non-null  float64
#  6   room_type_reserved                    32607 non-null  object
#  7   lead_time                             32607 non-null  int64
#  8   arrival_year                          32607 non-null  int64
#  9   arrival_month                         32607 non-null  int64
#  10  arrival_date                          32607 non-null  int64
# ...

# %%
df
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 32602             3               0                     2                  6
# 32603             2               0                     1                  3
# 32604             2               0                     2                  6
# 32605             2               0                     0                  3
# 32606             2               0                     1                  2
#
# ...

# %% [markdown]
# Membuat dataframe feature dan target untuk split

# %%
feature = df.drop(columns='booking_status', axis=1)
target = df['booking_status']

# %% [markdown]
# Melakukan split data 80% Train dan 20% Test

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, target, test_size=0.2, random_state=42)

# %% [markdown]
# Melihat hasil split data

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26085 entries, 5449 to 23654
# Data columns (total 17 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          26085 non-null  int64
#  1   no_of_children                        26085 non-null  int64
#  2   no_of_weekend_nights                  26085 non-null  int64
#  3   no_of_week_nights                     26085 non-null  int64
#  4   type_of_meal_plan                     26085 non-null  object
#  5   required_car_parking_space            26085 non-null  float64
#  6   room_type_reserved                    26085 non-null  object
#  7   lead_time                             26085 non-null  int64
#  8   arrival_year                          26085 non-null  int64
#  9   arrival_month                         26085 non-null  int64
#  10  arrival_date                          26085 non-null  int64
# ...

# %% [markdown]
# Melakukan encoding terhadap kolum kategorikal menggunakan OneHotEncode

# %%
categorical_cols = ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type']

# Inisialisasi encoder
OneEncode = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Fit dan transform hanya di data training
encoded_train = OneEncode.fit_transform(x_train[categorical_cols])
encoded_train_df = pd.DataFrame(
    encoded_train,
    columns=OneEncode.get_feature_names_out(categorical_cols),
    index=x_train.index  # Set index agar cocok saat concat
)

# Transform data testing (tanpa fit ulang)
encoded_test = OneEncode.transform(x_test[categorical_cols])
encoded_test_df = pd.DataFrame(
    encoded_test,
    columns=OneEncode.get_feature_names_out(categorical_cols),
    index=x_test.index  # Set index agar cocok saat concat
)

# Gabungkan dengan kolom numerik
x_train = pd.concat([x_train.drop(columns=categorical_cols), encoded_train_df], axis=1)
x_test = pd.concat([x_test.drop(columns=categorical_cols), encoded_test_df], axis=1)

# %% [markdown]
# Melihat hasil .info setelah encode

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26085 entries, 5449 to 23654
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          26085 non-null  int64
#  1   no_of_children                        26085 non-null  int64
#  2   no_of_weekend_nights                  26085 non-null  int64
#  3   no_of_week_nights                     26085 non-null  int64
#  4   required_car_parking_space            26085 non-null  float64
#  5   lead_time                             26085 non-null  int64
#  6   arrival_year                          26085 non-null  int64
#  7   arrival_month                         26085 non-null  int64
#  8   arrival_date                          26085 non-null  int64
#  9   repeated_guest                        26085 non-null  int64
#  10  no_of_previous_cancellations          26085 non-null  int64
# ...

# %% [markdown]
# Melakukan reset index agar entries (jumlah kolom dan baris) sama dan teratur

# %%
x_train = x_train.reset_index(drop=True)
x_test = x_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# Melakukan model fitting menggunakan random forest

# %%
RF_model = RandomForestClassifier(random_state=42)
RF_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
RF_pred = RF_model.predict(x_test)

# %% [markdown]
# Menampilkan Classification Report model Random Forest

# %%
print("Classification Report for Random Forest:")
print(classification_report(y_test, RF_pred, target_names=['Canceled', 'Not_Canceled']))
# Out:
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#     Canceled       0.89      0.80      0.84      2107
# Not_Canceled       0.91      0.95      0.93      4415
#
#     accuracy                           0.90      6522
#    macro avg       0.90      0.88      0.89      6522
# weighted avg       0.90      0.90      0.90      6522

# %% [markdown]
# Melakukan model fitting menggunakan XGBoost

# %%
XGB_model = XGBClassifier(random_state=42)
XGB_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
XGB_pred = XGB_model.predict(x_test)

# %% [markdown]
# Menampilkan Classification Report model XGBoost

# %%
print("Classification Report for XGBoost:")
print(classification_report(y_test, XGB_pred, target_names=['Canceled', 'Not_Canceled']))
# Out:
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#     Canceled       0.87      0.80      0.83      2107
# Not_Canceled       0.91      0.94      0.93      4415
#
#     accuracy                           0.90      6522
#    macro avg       0.89      0.87      0.88      6522
# weighted avg       0.90      0.90      0.90      6522

# %% [markdown]
# Simpan model terbaik (Random Forest) dalam bentuk pickel file (.pkl)

# %%
path_file = os.path.join('C://Users/narzo/Downloads/Code/Code Binus/Model Deploy', 'RF_model.pkl')
with open(path_file, 'wb') as file:
    joblib.dump(RF_model, file, compress=3)
